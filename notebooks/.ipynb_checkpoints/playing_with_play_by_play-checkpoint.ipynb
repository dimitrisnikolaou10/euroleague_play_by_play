# %%
import math
import pandas as pd
import numpy as np
df = pd.read_csv("../data/raw/playoff/round_3/KHIvsCSK.csv")

# %%
def adjustments():
    # change col name to Jersey
    df.rename(columns={"DORSAL": "JERSEY"},inplace=True)

    # delete empty columns
    del df["COMMENT"]
    del df["TYPE"]

    # get the int(min), int(sec) from time
    df["Q_MIN"] = df["MARKERTIME"].apply(lambda row: 0 if type(row) != str else int(row.split(":")[0]))
    df["Q_SEC"] = df["MARKERTIME"].apply(lambda row: 0 if type(row) != str else int(row.split(":")[1]))
    
    # remove blanks from CODETEAM
    df["CODETEAM"] = df["CODETEAM"].apply(lambda row: row[0:3])

    # get the points scored at the play from the cummulative
    df["POINTS_A"].fillna(method='ffill', inplace = True) 
    df["POINTS_B"].fillna(method='ffill', inplace = True)
    df["POINTS_A"].fillna(0, inplace = True)
    df["POINTS_B"].fillna(0, inplace = True)
    df["SCORE_A"] = df["POINTS_A"].diff()
    df["SCORE_B"] = df["POINTS_B"].diff()
    df["SCORE_A"].fillna(0, inplace = True)
    df["SCORE_B"].fillna(0, inplace = True)
    
adjustments()

# %%
# store the team code name
team_a_code = df.iloc[0,13]
team_b_code = df.iloc[0,15]

# store the seperate dfs, the respective indices and the respective last indices of team 
team_a_df = df[df["CODETEAM"]==team_a_code]
team_a_indices = team_a_df.index
last_team_a_index = team_a_indices[-1]
team_b_df = df[df["CODETEAM"]==team_b_code]
team_b_indices = team_b_df.index
last_team_b_index = team_b_indices[-1]

# store the sub keywords and create empty lists of the substition points
sub_words = ["IN","OUT"]
team_a_sub_points, team_b_sub_points = [], []

# go through the dataframes one by one and find each substitution point by flagging each point
# where there is no substitution keyword after a substitution keyword
row_iterator = team_a_df.iterrows()
for index, row in row_iterator:
    if row["PLAYTYPE"] in sub_words:
        next_index = index + 1
        if next_index > last_team_a_index:
            break
        while next_index not in team_a_indices:
            next_index += 1
            if next_index > last_team_a_index:
                break
        if team_a_df.loc[next_index,"PLAYTYPE"] not in sub_words:
            team_a_sub_points.append(index)
        
row_iterator = team_b_df.iterrows()
for index, row in row_iterator:
    if row["PLAYTYPE"] in sub_words:
        next_index = index + 1
        if next_index > last_team_b_index:
            break
        while next_index not in team_b_indices:
            next_index += 1
            if next_index > last_team_b_index:
                break
        if team_b_df.loc[next_index,"PLAYTYPE"] not in sub_words:
            team_b_sub_points.append(index)

# create a dictionary to store the lineups in with a key being the subsitution point as found before
# go through all substitution points and effectively segment the dataframe in sub point to sub point
# while doing so, go through each segment and append every player to the lineup list if he has not been
# appended before or if he is getting in now.
# also store the players that are getting in and the ones that are getting out so you can pass along a 
# clean version of the lineup list in the next loop
team_a_lineups = {}
start = 0
player_lineup = []
in_lineup = []
out_lineup = []
all_team_a_index = list(team_a_df.index)
for sub_point in team_a_sub_points:
    valid_indices = [item for item in team_a_indices if item >= start and item <= sub_point]
    for index in valid_indices:
        if type(team_a_df.loc[index, "PLAYER"]) is not str:
            continue
        
        if team_a_df.loc[index, "PLAYTYPE"] == "IN":
            in_lineup.append(team_a_df.loc[index, "PLAYER"])
            continue
        elif team_a_df.loc[index, "PLAYTYPE"] == "OUT":
            out_lineup.append(team_a_df.loc[index, "PLAYER"])
            
        if team_a_df.loc[index, "PLAYER"] not in player_lineup:
            player_lineup.append(team_a_df.loc[index, "PLAYER"])
            
        # in the case that not all 5 players have been in any plays until the first sub, keep looking
        # search in all the indices of the team and if its not a player that was subbed, append him to list
        if ((index == valid_indices[-1]) and (len(player_lineup) < 5)):
            indices_to_search_for_fifth = [i for i in all_team_a_index if i > index]
            for p in indices_to_search_for_fifth:
                if type(team_a_df.loc[p, "PLAYER"]) is not str:
                    continue
                elif team_a_df.loc[p, "PLAYTYPE"] in sub_words:
                    continue
                elif ((team_a_df.loc[p, "PLAYER"] not in player_lineup) and (team_a_df.loc[p, "PLAYER"] not in in_lineup)):
                    player_lineup.append(team_a_df.loc[p, "PLAYER"])
                
                if len(player_lineup)==5:
                    break
        
    team_a_lineups[sub_point] = player_lineup
    
    player_lineup = [player for player in player_lineup if player not in out_lineup]
    player_lineup = player_lineup + in_lineup
    
    out_lineup, in_lineup = [],[]
    
    start = sub_point + 1

team_b_lineups = {}
start = 0
player_lineup = []
in_lineup = []
out_lineup = []
all_team_b_index = list(team_b_df.index)
for sub_point in team_b_sub_points:
    valid_indices = [item for item in team_b_indices if item >= start and item <= sub_point]
    print(valid_indices)
    for index in valid_indices:
        #print(index)
        if type(team_b_df.loc[index, "PLAYER"]) is not str:
            continue
        
        if team_b_df.loc[index, "PLAYTYPE"] == "IN":
            in_lineup.append(team_b_df.loc[index, "PLAYER"])
        elif team_b_df.loc[index, "PLAYTYPE"] == "OUT":
            out_lineup.append(team_b_df.loc[index, "PLAYER"])
            
        if ((team_b_df.loc[index, "PLAYER"] not in player_lineup) and (team_b_df.loc[index, "PLAYTYPE"] != "IN")):
            player_lineup.append(team_b_df.loc[index, "PLAYER"])
            
        # in the case that not all 5 players have been in any plays until the first sub, keep looking
        # search in all the indices of the team and if its not a player that was subbed, append him to list
        print(index, valid_indices[-1])
        if ((index == valid_indices[-1]) and (len(player_lineup) < 5)):
            indices_to_search_for_fifth = [i for i in all_team_b_index if i > index]
            for p in indices_to_search_for_fifth:
                if type(team_b_df.loc[p, "PLAYER"]) is not str:
                    continue
                elif team_b_df.loc[p, "PLAYTYPE"] in sub_words:
                    continue
                elif ((team_b_df.loc[p, "PLAYER"] not in player_lineup) and (team_b_df.loc[p, "PLAYER"] not in in_lineup)):
                    player_lineup.append(team_b_df.loc[p, "PLAYER"])
                
                if len(player_lineup)==5:
                    break
        
    team_b_lineups[sub_point] = player_lineup
    
    player_lineup = [player for player in player_lineup if player not in out_lineup]
    player_lineup = player_lineup + in_lineup
    
    out_lineup, in_lineup = [],[]
    
    start = sub_point + 1
# Out:
# [2, 4, 5, 8, 9, 10]
# 2 10
# 4 10
# 5 10
# 8 10
# 9 10
# 10 10
# [12, 13, 15, 17, 18, 21, 22, 23, 24, 25, 29, 31, 32, 36, 38, 40, 42, 44, 45, 49, 51, 56, 57, 60, 61, 63, 64, 67, 69, 70, 73, 75, 76, 79, 82, 83, 84]
# 12 84
# 13 84
# 15 84
# 17 84
# 18 84
# 21 84
# 22 84
# 23 84
# 24 84
# 25 84
# 29 84
# 31 84
# 32 84
# 36 84
# 38 84
# 42 84
# 44 84
# 45 84
# 49 84
# 51 84
# 56 84
# 57 84
# 60 84
# 61 84
# 63 84
# 64 84
# 67 84
# 69 84
# 70 84
# 73 84
# 75 84
# 76 84
# 79 84
# 83 84
# 84 84
# [85, 89, 90]
# 85 90
# 89 90
# 90 90
# [91, 92, 95, 96, 97, 99, 100, 101]
# 91 101
# 92 101
# 95 101
# 96 101
# 97 101
# 99 101
# 100 101
# 101 101
# [103, 104, 107, 109, 110, 118, 122, 123, 124]
# 103 124
# 104 124
# 107 124
# 109 124
# 110 124
# 118 124
# 122 124
# 123 124
# 124 124
# [128, 131, 132, 133]
# 128 133
# 131 133
# 132 133
# 133 133
# [135, 136, 137, 140, 141, 142, 143, 144, 145]
# 135 145
# 136 145
# 137 145
# 140 145
# 142 145
# 143 145
# 144 145
# 145 145
# [146, 149, 150, 153, 156, 157]
# 146 157
# 150 157
# 153 157
# 156 157
# 157 157
# [158, 160, 161, 163, 164, 165, 166, 167, 168, 170, 171, 174, 176, 179, 180, 184, 185, 188, 191, 192, 197, 198, 200, 201, 204, 206, 207, 208, 209]
# 158 209
# 160 209
# 161 209
# 163 209
# 164 209
# 165 209
# 166 209
# 167 209
# 168 209
# 170 209
# 171 209
# 174 209
# 176 209
# 179 209
# 184 209
# 185 209
# 188 209
# 191 209
# 192 209
# 197 209
# 198 209
# 200 209
# 201 209
# 204 209
# 206 209
# 207 209
# 208 209
# 209 209
# [210, 211, 213, 214, 216, 219, 220, 221, 222, 223, 226, 227]
# 210 227
# 211 227
# 213 227
# 214 227
# 216 227
# 219 227
# 220 227
# 222 227
# 223 227
# 226 227
# 227 227
# [229, 230, 232, 233, 236, 238, 243, 247, 248]
# 229 248
# 230 248
# 232 248
# 233 248
# 236 248
# 238 248
# 243 248
# 247 248
# 248 248
# [250, 255, 267, 268, 269, 270]
# 250 270
# 255 270
# 267 270
# 268 270
# 269 270
# 270 270
# [271, 274, 275, 276, 277, 284, 286, 287, 288, 289, 291, 292, 293, 294, 299, 300, 302, 307, 308, 312, 313, 316, 317, 318, 320, 321, 324, 326, 327, 332, 334, 335, 336, 337, 339, 340, 341]
# 271 341
# 274 341
# 275 341
# 276 341
# 277 341
# 284 341
# 286 341
# 287 341
# 288 341
# 289 341
# 291 341
# 292 341
# 293 341
# 294 341
# 299 341
# 300 341
# 302 341
# 307 341
# 308 341
# 312 341
# 313 341
# 316 341
# 317 341
# 318 341
# 320 341
# 321 341
# 326 341
# 327 341
# 332 341
# 334 341
# 335 341
# 336 341
# 337 341
# 339 341
# 340 341
# 341 341
# [343, 344, 346, 347, 349, 354, 357, 358, 359]
# 343 359
# 344 359
# 346 359
# 347 359
# 349 359
# 354 359
# 357 359
# 358 359
# 359 359
# [361, 366, 367, 369, 370]
# 361 370
# 366 370
# 367 370
# 369 370
# 370 370
# [372, 373, 376, 377, 379, 385, 386]
# 372 386
# 373 386
# 376 386
# 377 386
# 379 386
# 385 386
# 386 386
# [387, 392, 394, 395, 396, 399, 404, 405, 408, 409, 413, 416, 417, 420, 421, 422, 423]
# 387 423
# 392 423
# 394 423
# 395 423
# 396 423
# 404 423
# 408 423
# 409 423
# 413 423
# 416 423
# 417 423
# 420 423
# 421 423
# 422 423
# 423 423
# [424, 425, 428, 429]
# 424 429
# 425 429
# 428 429
# 429 429
# [430, 431, 432, 433, 437, 438, 439, 441, 442, 443, 447, 448, 449, 450, 451, 455, 456, 459, 460, 461]
# 430 461
# 431 461
# 432 461
# 433 461
# 437 461
# 438 461
# 439 461
# 441 461
# 442 461
# 443 461
# 447 461
# 448 461
# 449 461
# 450 461
# 451 461
# 455 461
# 456 461
# 460 461
# 461 461
# [462, 465, 467, 468]
# 462 468
# 465 468
# 467 468
# 468 468
# [470, 471, 473, 474, 479, 481, 482]
# 470 482
# 471 482
# 473 482
# 474 482
# 479 482
# 481 482
# 482 482

# %%
team_b_lineups
# Out:
# {10: ['HUNTER, OTHELLO',
#   'RODRIGUEZ, SERGIO',
#   'KURBANOV, NIKITA',
#   'ANTONOV, SEMEN',
#   'HIGGINS, CORY'],
#  84: ['HUNTER, OTHELLO',
#   'RODRIGUEZ, SERGIO',
#   'KURBANOV, NIKITA',
#   'HIGGINS, CORY',
#   'CLYBURN, WILL'],
#  90: ['HUNTER, OTHELLO',
#   'KURBANOV, NIKITA',
#   'HIGGINS, CORY',
#   'CLYBURN, WILL',
#   'WESTERMANN, LEO'],
#  101: ['HUNTER, OTHELLO',
#   'HIGGINS, CORY',
#   'CLYBURN, WILL',
#   'WESTERMANN, LEO',
#   'ANTONOV, SEMEN'],
#  124: ['HIGGINS, CORY',
#   'CLYBURN, WILL',
#   'WESTERMANN, LEO',
#   'ANTONOV, SEMEN',
#   'VORONTSEVICH, ANDREY'],
#  133: ['HIGGINS, CORY',
#   'CLYBURN, WILL',
#   'WESTERMANN, LEO',
#   'VORONTSEVICH, ANDREY',
#   'RUDD, VICTOR'],
#  145: ['CLYBURN, WILL',
#   'WESTERMANN, LEO',
#   'VORONTSEVICH, ANDREY',
#   'RUDD, VICTOR',
#   'FRIDZON, VITALY'],
#  157: ['CLYBURN, WILL',
#   'VORONTSEVICH, ANDREY',
#   'FRIDZON, VITALY',
#   'RODRIGUEZ, SERGIO',
#   'HUNTER, OTHELLO'],
#  209: ['VORONTSEVICH, ANDREY',
#   'FRIDZON, VITALY',
#   'RODRIGUEZ, SERGIO',
#   'HUNTER, OTHELLO',
#   'HIGGINS, CORY'],
#  227: ['RODRIGUEZ, SERGIO',
#   'HUNTER, OTHELLO',
#   'HIGGINS, CORY',
#   'RUDD, VICTOR',
#   'KURBANOV, NIKITA',
#   'VORONTSEVICH, ANDREY'],
#  248: ['RODRIGUEZ, SERGIO',
#   'HIGGINS, CORY',
#   'RUDD, VICTOR',
#   'KURBANOV, NIKITA',
#   'VORONTSEVICH, ANDREY',
#   'CLYBURN, WILL'],
#  270: ['HIGGINS, CORY',
#   'RUDD, VICTOR',
#   'KURBANOV, NIKITA',
#   'VORONTSEVICH, ANDREY',
#   'CLYBURN, WILL',
#   'WESTERMANN, LEO'],
#  341: ['HIGGINS, CORY',
#   'KURBANOV, NIKITA',
#   'VORONTSEVICH, ANDREY',
#   'CLYBURN, WILL',
#   'RODRIGUEZ, SERGIO',
#   'HUNTER, OTHELLO'],
#  359: ['HIGGINS, CORY',
#   'KURBANOV, NIKITA',
#   'VORONTSEVICH, ANDREY',
#   'CLYBURN, WILL',
#   'RODRIGUEZ, SERGIO',
#   'ANTONOV, SEMEN'],
#  370: ['HIGGINS, CORY',
#   'KURBANOV, NIKITA',
#   'VORONTSEVICH, ANDREY',
#   'CLYBURN, WILL',
#   'ANTONOV, SEMEN',
#   'WESTERMANN, LEO'],
#  386: ['HIGGINS, CORY',
#   'KURBANOV, NIKITA',
#   'VORONTSEVICH, ANDREY',
#   'CLYBURN, WILL',
#   'WESTERMANN, LEO',
#   'VORONTSEVICH, ANDREY'],
#  423: ['HIGGINS, CORY',
#   'KURBANOV, NIKITA',
#   'CLYBURN, WILL',
#   'WESTERMANN, LEO',
#   'RUDD, VICTOR'],
#  429: ['KURBANOV, NIKITA',
#   'CLYBURN, WILL',
#   'WESTERMANN, LEO',
#   'RODRIGUEZ, SERGIO',
#   'HUNTER, OTHELLO'],
#  461: ['CLYBURN, WILL',
#   'WESTERMANN, LEO',
#   'RODRIGUEZ, SERGIO',
#   'HUNTER, OTHELLO',
#   'FRIDZON, VITALY'],
#  468: ['CLYBURN, WILL',
#   'RODRIGUEZ, SERGIO',
#   'HUNTER, OTHELLO',
#   'FRIDZON, VITALY',
#   'HIGGINS, CORY'],
#  482: ['RODRIGUEZ, SERGIO',
#   'HUNTER, OTHELLO',
#   'FRIDZON, VITALY',
#   'HIGGINS, CORY',
#   'KURBANOV, NIKITA']}

# %%
#create new columns to store the lineups in
df["home_team_player_1"]=np.nan
df["home_team_player_2"]=np.nan
df["home_team_player_3"]=np.nan
df["home_team_player_4"]=np.nan
df["home_team_player_5"]=np.nan

df["away_team_player_1"]=np.nan
df["away_team_player_2"]=np.nan
df["away_team_player_3"]=np.nan
df["away_team_player_4"]=np.nan
df["away_team_player_5"]=np.nan

#add home team lineups to main dataframe
start_index = 0
for end_index in team_a_lineups:
    df.loc[start_index:end_index,"home_team_player_1"] = team_a_lineups[end_index][0]
    df.loc[start_index:end_index,"home_team_player_2"] = team_a_lineups[end_index][1]
    df.loc[start_index:end_index,"home_team_player_3"] = team_a_lineups[end_index][2]
    df.loc[start_index:end_index,"home_team_player_4"] = team_a_lineups[end_index][3]
    df.loc[start_index:end_index,"home_team_player_5"] = team_a_lineups[end_index][4]
    start_index = end_index

#add away team lineups to main dataframe
start_index = 0
for end_index in team_b_lineups:
    df.loc[start_index:end_index,"away_team_player_1"] = team_b_lineups[end_index][0]
    df.loc[start_index:end_index,"away_team_player_2"] = team_b_lineups[end_index][1]
    df.loc[start_index:end_index,"away_team_player_3"] = team_b_lineups[end_index][2]
    df.loc[start_index:end_index,"away_team_player_4"] = team_b_lineups[end_index][3]
    df.loc[start_index:end_index,"away_team_player_5"] = team_b_lineups[end_index][4]
    start_index = end_index

#forward fill as last subs stayed until end of game
df["home_team_player_1"].fillna(method='ffill', inplace = True)
df["home_team_player_2"].fillna(method='ffill', inplace = True)
df["home_team_player_3"].fillna(method='ffill', inplace = True)
df["home_team_player_4"].fillna(method='ffill', inplace = True)
df["home_team_player_5"].fillna(method='ffill', inplace = True)

df["away_team_player_1"].fillna(method='ffill', inplace = True)
df["away_team_player_2"].fillna(method='ffill', inplace = True)
df["away_team_player_3"].fillna(method='ffill', inplace = True)
df["away_team_player_4"].fillna(method='ffill', inplace = True)
df["away_team_player_5"].fillna(method='ffill', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-457-e91ddc9f4f77> in <module>()
#      29     df.loc[start_index:end_index,"away_team_player_3"] = team_b_lineups[end_index][2]
#      30     df.loc[start_index:end_index,"away_team_player_4"] = team_b_lineups[end_index][3]
# ---> 31     df.loc[start_index:end_index,"away_team_player_5"] = team_b_lineups[end_index][4]
#      32     start_index = end_index
#      33
#
# IndexError: list index out of range

# %%
team_b_df
# Out:
#     CODETEAM  JERSEY MARKERTIME  MINUTE  NUMBEROFPLAY                PLAYER  \
# 2        CSK    44.0      10:00       1             4       HUNTER, OTHELLO
# 4        CSK    13.0      09:31       1             6     RODRIGUEZ, SERGIO
# 5        CSK    41.0      09:19       1             7      KURBANOV, NIKITA
# 8        CSK    41.0      09:08       1            10      KURBANOV, NIKITA
# 9        CSK    11.0      09:08       1            11        ANTONOV, SEMEN
# 10       CSK    21.0      09:08       1            12         CLYBURN, WILL
# 12       CSK    22.0      08:56       2            15         HIGGINS, CORY
# 13       CSK    22.0      08:56       2            16         HIGGINS, CORY
# 15       CSK    41.0      08:49       2            18      KURBANOV, NIKITA
# 17       CSK    44.0      08:32       2            20       HUNTER, OTHELLO
# 18       CSK    13.0      08:24       2            21     RODRIGUEZ, SERGIO
# 21       CSK    21.0      08:06       2            24         CLYBURN, WILL
# 22       CSK    13.0      07:54       3            26     RODRIGUEZ, SERGIO
# 23       CSK    44.0      07:53       3            27       HUNTER, OTHELLO
# 24       CSK    44.0      07:53       3            28       HUNTER, OTHELLO
# 25       CSK    44.0      07:53       3            29       HUNTER, OTHELLO
# 29       CSK    44.0      07:53       3            33       HUNTER, OTHELLO
# 31       CSK    44.0      07:36       3            35       HUNTER, OTHELLO
# 32       CSK    22.0      07:30       3            36         HIGGINS, CORY
# 36       CSK    13.0      07:03       3            40     RODRIGUEZ, SERGIO
# 38       CSK    22.0      06:55       4            43         HIGGINS, CORY
# 40       CSK     NaN      06:40       4            45                   NaN
# 42       CSK    22.0      06:05       4            47         HIGGINS, CORY
# 44       CSK    21.0      05:47       5            50         CLYBURN, WILL
# 45       CSK    41.0      05:36       5            51      KURBANOV, NIKITA
# 49       CSK    44.0      05:23       5            55       HUNTER, OTHELLO
# 51       CSK    22.0      05:03       5            57         HIGGINS, CORY
# 56       CSK    13.0      04:45       6            63     RODRIGUEZ, SERGIO
# 57       CSK    22.0      04:45       6            64         HIGGINS, CORY
# 60       CSK    22.0      04:45       6            67         HIGGINS, CORY
# 61       CSK    22.0      04:45       6            68         HIGGINS, CORY
# 63       CSK    21.0      04:22       6            70         CLYBURN, WILL
# 64       CSK    13.0      04:18       6            71     RODRIGUEZ, SERGIO
# 67       CSK    44.0      03:39       7            75       HUNTER, OTHELLO
# 69       CSK    21.0      03:08       7            77         CLYBURN, WILL
# 70       CSK    21.0      03:07       7            78         CLYBURN, WILL
# 73       CSK    41.0      02:58       8            82      KURBANOV, NIKITA
# 75       CSK    41.0      02:58       8            84      KURBANOV, NIKITA
# 76       CSK    41.0      02:58       8            85      KURBANOV, NIKITA
# 79       CSK    13.0      02:22       8            88     RODRIGUEZ, SERGIO
# 82       CSK     NaN      02:02       8            91                   NaN
# 83       CSK     9.0      02:02       8            92       WESTERMANN, LEO
# 84       CSK    13.0      02:02       8            93     RODRIGUEZ, SERGIO
# 85       CSK     9.0      01:44       9            95       WESTERMANN, LEO
# 89       CSK    11.0      01:44       9            99        ANTONOV, SEMEN
# 90       CSK    41.0      01:44       9           100      KURBANOV, NIKITA
# 91       CSK     9.0      01:44       9           101       WESTERMANN, LEO
# 92       CSK     9.0      01:44       9           102       WESTERMANN, LEO
# 95       CSK    22.0      01:21       9           105         HIGGINS, CORY
# 96       CSK    22.0      01:20       9           106         HIGGINS, CORY
# 97       CSK    22.0      01:18       9           107         HIGGINS, CORY
# 99       CSK    11.0      01:08       9           109        ANTONOV, SEMEN
# 100      CSK    20.0      01:08       9           110  VORONTSEVICH, ANDREY
# 101      CSK    44.0      01:08       9           111       HUNTER, OTHELLO
# 103      CSK    11.0      00:53      10           114        ANTONOV, SEMEN
# 104      CSK    20.0      00:35      10           115  VORONTSEVICH, ANDREY
# 107      CSK     9.0      00:33      10           118       WESTERMANN, LEO
# 109      CSK    11.0      00:21      10           120        ANTONOV, SEMEN
# 110      CSK    21.0      00:00      10           121         CLYBURN, WILL
# 118      CSK     9.0      09:46      11           130       WESTERMANN, LEO
# 122      CSK    11.0      09:24      11           134        ANTONOV, SEMEN
# 123      CSK     3.0      09:24      11           135          RUDD, VICTOR
# 124      CSK    11.0      09:24      11           136        ANTONOV, SEMEN
# 128      CSK     3.0      09:00      11           140          RUDD, VICTOR
# 131      CSK    20.0      08:52      12           144  VORONTSEVICH, ANDREY
# 132      CSK     7.0      08:52      12           145       FRIDZON, VITALY
# 133      CSK    22.0      08:52      12           146         HIGGINS, CORY
# 135      CSK     3.0      08:32      12           148          RUDD, VICTOR
# 136      CSK    21.0      08:32      12           149         CLYBURN, WILL
# 137      CSK     9.0      08:07      12           150       WESTERMANN, LEO
# 140      CSK     7.0      07:24      13           154       FRIDZON, VITALY
# 141      CSK     NaN      07:24      13           155                   NaN
# 142      CSK     3.0      07:24      13           156          RUDD, VICTOR
# 143      CSK     9.0      07:24      13           157       WESTERMANN, LEO
# 144      CSK    13.0      07:24      13           158     RODRIGUEZ, SERGIO
# 145      CSK    44.0      07:24      13           159       HUNTER, OTHELLO
# 146      CSK    21.0      07:12      13           160         CLYBURN, WILL
# 149      CSK     NaN      07:02      13           163                   NaN
# 150      CSK    21.0      06:46      14           165         CLYBURN, WILL
# 153      CSK    13.0      06:44      14           168     RODRIGUEZ, SERGIO
# 441      CSK    21.0      05:36      35           480         CLYBURN, WILL
# 442      CSK    21.0      05:36      35           481         CLYBURN, WILL
# 443      CSK    21.0      05:36      35           482         CLYBURN, WILL
# 447      CSK    21.0      05:36      35           486         CLYBURN, WILL
# 448      CSK    44.0      05:36      35           487       HUNTER, OTHELLO
# 449      CSK    44.0      05:36      35           488       HUNTER, OTHELLO
# 450      CSK    44.0      05:36      35           489       HUNTER, OTHELLO
# 451      CSK    44.0      05:34      35           490       HUNTER, OTHELLO
# 455      CSK    44.0      05:34      35           494       HUNTER, OTHELLO
# 456      CSK    44.0      05:34      35           495       HUNTER, OTHELLO
# 459      CSK     NaN      05:20      35           498                   NaN
# 460      CSK     9.0      05:20      35           499       WESTERMANN, LEO
# 461      CSK    22.0      05:20      35           500         HIGGINS, CORY
# 462      CSK    21.0      04:58      36           502         CLYBURN, WILL
# 465      CSK     7.0      04:41      36           505       FRIDZON, VITALY
# 467      CSK    21.0      04:27      36           507         CLYBURN, WILL
# 468      CSK    41.0      04:27      36           508      KURBANOV, NIKITA
# 470      CSK    13.0      04:13      36           510     RODRIGUEZ, SERGIO
# 471      CSK    22.0      04:04      36           511         HIGGINS, CORY
# 473      CSK    44.0      03:54      37           514       HUNTER, OTHELLO
# 474      CSK    44.0      03:54      37           515       HUNTER, OTHELLO
# 479      CSK    22.0      03:34      37           520         HIGGINS, CORY
# 481      CSK     7.0      03:34      37           522       FRIDZON, VITALY
# 482      CSK    21.0      03:34      37           523         CLYBURN, WILL
# 485      CSK     NaN      03:29      37           526                   NaN
# 486      CSK    44.0      03:15      37           527       HUNTER, OTHELLO
# 490      CSK    13.0      02:49      38           532     RODRIGUEZ, SERGIO
# 492      CSK    41.0      02:25      38           534      KURBANOV, NIKITA
# 493      CSK    13.0      02:25      38           535     RODRIGUEZ, SERGIO
# 495      CSK    13.0      02:25      38           537     RODRIGUEZ, SERGIO
# 496      CSK    13.0      02:25      38           538     RODRIGUEZ, SERGIO
# 498      CSK    22.0      02:03      38           540         HIGGINS, CORY
# 499      CSK    21.0      01:58      39           542         CLYBURN, WILL
# 501      CSK    21.0      01:58      39           544         CLYBURN, WILL
# 502      CSK    21.0      01:58      39           545         CLYBURN, WILL
# 503      CSK    22.0      01:58      39           546         HIGGINS, CORY
# 507      CSK    21.0      01:38      39           550         CLYBURN, WILL
# 508      CSK    21.0      01:33      39           551         CLYBURN, WILL
# 511      CSK    41.0      01:30      39           554      KURBANOV, NIKITA
# 513      CSK    41.0      01:08      39           556      KURBANOV, NIKITA
# 514      CSK    41.0      00:47      40           558      KURBANOV, NIKITA
# 517      CSK    13.0      00:46      40           561     RODRIGUEZ, SERGIO
# 519      CSK    13.0      00:19      40           563     RODRIGUEZ, SERGIO
# 521      CSK    13.0      00:19      40           565     RODRIGUEZ, SERGIO
# 522      CSK    13.0      00:19      40           566     RODRIGUEZ, SERGIO
# 523      CSK    13.0      00:19      40           567     RODRIGUEZ, SERGIO
# 525      CSK    13.0      00:18      40           569     RODRIGUEZ, SERGIO
# 528      CSK    13.0      00:11      40           572     RODRIGUEZ, SERGIO
# 534      CSK    22.0      00:07      40           578         HIGGINS, CORY
# 537      CSK    13.0      00:00      40           582     RODRIGUEZ, SERGIO
#
#       PLAYER_ID                             PLAYINFO PLAYTYPE  POINTS_A  \
# 2    P005160                                     NaN    TPOFF       0.0
# 4    PCVM                            Def Rebound (1)        D       0.0
# 5    PJLX           Missed Two Pointer (0/1 -  0 pt)     2FGA       0.0
# 8    PJLX                                   Foul (1)       CM       0.0
# 9    P004941                                     Out      OUT       0.0
# 10   P004888                                      In       IN       0.0
# 12   P006450                         Def Rebound (1)        D       0.0
# 13   P006450                          Foul Drawn (1)       RV       0.0
# 15   PJLX                  Two Pointer (1/2 -  2 pt)     2FGM       0.0
# 17   P005160                         Def Rebound (1)        D       0.0
# 18   PCVM                               Turnover (1)       TO       0.0
# 21   P004888                         Def Rebound (1)        D       0.0
# 22   PCVM           Missed Two Pointer (0/1 -  0 pt)     2FGA       0.0
# 23   P005160                         Off Rebound (1)        O       0.0
# 24   P005160               Two Pointer (1/1 -  2 pt)     2FGM       0.0
# 25   P005160                          Foul Drawn (1)       RV       0.0
# 29   P005160             Free Throw In (1/1 -  3 pt)      FTM       0.0
# 31   P005160                         Def Rebound (2)        D       0.0
# 32   P006450      Missed Three Pointer (0/1 -  0 pt)     3FGA       0.0
# 36   PCVM                             Foul Drawn (1)       RV       2.0
# 38   P006450                          Foul Drawn (2)       RV       2.0
# 40                                      Turnover (1)       TO       2.0
# 42   P006450               Two Pointer (1/1 -  2 pt)     2FGM       5.0
# 44   P004888                         Def Rebound (2)        D       5.0
# 45   PJLX                               Turnover (1)       TO       5.0
# 49   P005160                                Foul (1)       CM       7.0
# 51   P006450        Missed Two Pointer (1/2 -  2 pt)     2FGA       8.0
# 56   PCVM                                  Steal (1)       ST       8.0
# 57   P006450                          Foul Drawn (3)       RV       8.0
# 60   P006450             Free Throw In (1/1 -  3 pt)      FTM       8.0
# 61   P006450             Free Throw In (2/2 -  4 pt)      FTM       8.0
# 63   P004888                         Def Rebound (3)        D       8.0
# 64   PCVM                               Turnover (2)       TO       8.0
# 67   P005160                            Turnover (1)       TO      10.0
# 69   P004888                         Def Rebound (4)        D      10.0
# 70   P004888                            Turnover (1)       TO      10.0
# 73   PJLX                             Foul Drawn (1)       RV      12.0
# 75   PJLX                Free Throw In (1/1 -  3 pt)      FTM      12.0
# 76   PJLX                Free Throw In (2/2 -  4 pt)      FTM      12.0
# 79   PCVM         Missed Three Pointer (0/1 -  0 pt)     3FGA      14.0
# 82                                      Time Out (1)     TOUT      17.0
# 83   P002543                                      In       IN      17.0
# 84   PCVM                                        Out      OUT      17.0
# 85   P002543                          Foul Drawn (1)       RV      17.0
# 89   P004941                                      In       IN      17.0
# 90   PJLX                                        Out      OUT      17.0
# 91   P002543             Free Throw In (1/1 -  1 pt)      FTM      17.0
# 92   P002543             Free Throw In (2/2 -  2 pt)      FTM      17.0
# 95   P006450                               Block (1)       FV      17.0
# 96   P006450                         Def Rebound (2)        D      17.0
# 97   P006450               Two Pointer (2/3 -  6 pt)     2FGM      17.0
# 99   P004941                                Foul (1)       CM      17.0
# 207  PLLH                                        Out      OUT      35.0
# 208  PLHI                                        Out      OUT      35.0
# 209  PJLX                                         In       IN      35.0
# 210  PCVM                Three Pointer (1/3 -  3 pt)     3FGM      35.0
# 211  P006450                              Assist (1)       AS      35.0
# 213  P006450              Two Pointer (4/6 -  15 pt)     2FGM      35.0
# 214  PCVM                                 Assist (2)       AS      35.0
# 216  PCVM         Missed Three Pointer (1/4 -  3 pt)     3FGA      37.0
# 219  P006536                               Steal (1)       ST      37.0
# 220  PLHI           Missed Two Pointer (0/1 -  0 pt)     2FGA      37.0
# 221                                  Off Rebound (3)        O      37.0
# 222  P006450              Two Pointer (5/7 -  17 pt)     2FGM      37.0
# 223  PCVM                                 Assist (3)       AS      37.0
# 226  P004888                                      In       IN      37.0
# 227  P005160                                     Out      OUT      37.0
# 229  P006450                          Foul Drawn (6)       RV      37.0
# 230  P006450            Free Throw In (5/5 -  18 pt)      FTM      37.0
# 232  PJLX                            Def Rebound (1)        D      37.0
# 233  PJLX                               Turnover (2)       TO      37.0
# 236  PCVM                  Two Pointer (1/2 -  5 pt)     2FGM      40.0
# 238  P006536                                Foul (1)       CM      40.0
# 243  PCVM                Three Pointer (2/5 -  8 pt)     3FGM      42.0
# 247  P002543                                      In       IN      42.0
# 248  PCVM                                        Out      OUT      42.0
# 250  P006450                                Foul (1)       CM      42.0
# 255  P004888                            Turnover (3)       TO      44.0
# 267  P006536                                     Out      OUT      44.0
# 268  P002543                                     Out      OUT      44.0
# 269  PCVM                                         In       IN      44.0
# 270  P005160                                      In       IN      44.0
# 271  P004888                          Foul Drawn (1)       RV      44.0
# 274  PJLX           Missed Two Pointer (1/3 -  4 pt)     2FGA      44.0
# 275  P005160                         Off Rebound (4)        O      44.0
# 276  P005160        Missed Two Pointer (3/4 -  8 pt)     2FGA      44.0
# 277  P005160                       Shot Rejected (1)       AG      44.0
# 284  P004888                          Foul Drawn (2)       RV      46.0
# 286  P004888         Missed Free Throw (0/1 -  2 pt)      FTA      46.0
# 287  P004888         Missed Free Throw (0/2 -  2 pt)      FTA      46.0
# 288  PJLX                            Off Rebound (1)        O      46.0
# 289  PJLX                  Two Pointer (2/4 -  6 pt)     2FGM      46.0
# 291  P004888                         Def Rebound (5)        D      46.0
# 292  P006450            Three Pointer (2/3 -  21 pt)     3FGM      46.0
# 293  PCVM                                 Assist (4)       AS      46.0
# 294  P006450                          Foul Drawn (7)       RV      46.0
# 299  P006450            Three Pointer (3/4 -  24 pt)     3FGM      46.0
# 300  PCVM                                 Assist (5)       AS      46.0
# 302  PJLX                                   Foul (2)       CM      46.0
# 307  P004888        Missed Two Pointer (1/3 -  2 pt)     2FGA      48.0
# 308  P004888                       Shot Rejected (1)       AG      48.0
# 312  P005160                         Def Rebound (3)        D      48.0
# 313  P004888      Missed Three Pointer (0/1 -  2 pt)     3FGA      48.0
# 316  PCVM                            Def Rebound (2)        D      48.0
# 317  P005160              Two Pointer (4/5 -  10 pt)     2FGM      48.0
# 318  PCVM                                 Assist (6)       AS      48.0
# 320  P005160                         Def Rebound (4)        D      48.0
# 321  PCVM                             Foul Drawn (3)       RV      48.0
# 324                                     Turnover (2)       TO      48.0
# 326  PJLX                            Def Rebound (2)        D      48.0
# 327  P006450       Missed Two Pointer (5/8 -  24 pt)     2FGA      48.0
# 332  P005160                                Foul (3)       CM      50.0
# 334  P005160                         Def Rebound (5)        D      50.0
# 335  PCVM           Missed Two Pointer (1/3 -  8 pt)     2FGA      50.0
# 336  P005160                         Off Rebound (5)        O      50.0
# 337  P005160              Two Pointer (5/6 -  12 pt)     2FGM      50.0
# 339  PCVM                               Turnover (3)       TO      52.0
# 340  P004941                                      In       IN      52.0
# 341  P005160                                     Out      OUT      52.0
# 343  PJLX                                  Steal (1)       ST      52.0
# 344  PJLX                             Foul Drawn (2)       RV      52.0
# 346  PJLX            Missed Free Throw (2/3 -  6 pt)      FTA      52.0
# 347  PJLX                Free Throw In (3/4 -  7 pt)      FTM      52.0
# 349  P004888        Missed Two Pointer (1/4 -  2 pt)     2FGA      54.0
# 354  PCVM         Missed Three Pointer (2/6 -  8 pt)     3FGA      56.0
# 357  P004941                                Foul (3)       CM      56.0
# 358  P002543                                      In       IN      56.0
# 359  PCVM                                        Out      OUT      56.0
# 361  P004888                                Foul (1)       CM      56.0
# 366  P004941                      Offensive Foul (4)       OF      58.0
# 367  P004941                            Turnover (1)       TO      58.0
# 369  P004941                                     Out      OUT      58.0
# 370  PLHI                                         In       IN      58.0
# 372  P006450                         Def Rebound (4)        D      58.0
# 373  P002543      Missed Three Pointer (0/3 -  2 pt)     3FGA      58.0
# 376  PLHI                            Def Rebound (1)        D      58.0
# 377  P006450              Two Pointer (6/9 -  26 pt)     2FGM      58.0
# 379  P002543      Missed Three Pointer (0/4 -  2 pt)     3FGA      60.0
# 385  P006536                                      In       IN      60.0
# 386  PLHI                                        Out      OUT      60.0
# 387  PJLX         Missed Three Pointer (0/1 -  7 pt)     3FGA      60.0
# 392  PJLX                                   Foul (3)       CM      62.0
# 394  P004888                         Def Rebound (6)        D      62.0
# 395  P006450      Missed Two Pointer (6/10 -  26 pt)     2FGA      62.0
# 396  P006450                       Shot Rejected (1)       AG      62.0
# 399  CO_B                             Bench Foul (1)        B      62.0
# 404  P002543                                Foul (2)       CM      63.0
# 405                                     Time Out (1)     TOUT      63.0
# 408  P004888                         Def Rebound (7)        D      63.0
# 409  P006536        Missed Two Pointer (0/2 -  0 pt)     2FGA      63.0
# 413  P002543                            Turnover (1)       TO      65.0
# 416  PJLX                            Def Rebound (3)        D      65.0
# 417  P006450                            Turnover (1)       TO      65.0
# 420  P006536                                     Out      OUT      65.0
# 421  PCVM                                         In       IN      65.0
# 422  P006450                                     Out      OUT      65.0
# 423  P005160                                      In       IN      65.0
# 424  P005160              Two Pointer (6/7 -  14 pt)     2FGM      65.0
# 425  PCVM                                 Assist (7)       AS      65.0
# 428  PLLH                                         In       IN      65.0
# 429  PJLX                                        Out      OUT      65.0
# 430  PCVM         Missed Three Pointer (2/7 -  8 pt)     3FGA      65.0
# 431  PCVM                            Off Rebound (1)        O      65.0
# 432  P004888        Missed Two Pointer (1/5 -  2 pt)     2FGA      65.0
# 433  P004888                       Shot Rejected (2)       AG      65.0
# 437  P002543                         Def Rebound (1)        D      65.0
# 438  P004888               Two Pointer (2/6 -  4 pt)     2FGM      65.0
# 439  PCVM                                 Assist (8)       AS      65.0
# 441  P004888                               Steal (1)       ST      65.0
# 442  P004888               Two Pointer (3/7 -  6 pt)     2FGM      65.0
# 443  P004888                          Foul Drawn (3)       RV      65.0
# 447  P004888         Missed Free Throw (0/3 -  6 pt)      FTA      65.0
# 448  P005160                         Off Rebound (6)        O      65.0
# 449  P005160       Missed Two Pointer (6/8 -  14 pt)     2FGA      65.0
# 450  P005160                         Off Rebound (7)        O      65.0
# 451  P005160                          Foul Drawn (3)       RV      65.0
# 455  P005160            Free Throw In (3/3 -  15 pt)      FTM      65.0
# 456  P005160            Free Throw In (4/4 -  16 pt)      FTM      65.0
# 459                                     Time Out (2)     TOUT      68.0
# 460  P002543                                     Out      OUT      68.0
# 461  P006450                                      In       IN      68.0
# 462  P004888      Missed Three Pointer (0/2 -  6 pt)     3FGA      68.0
# 465  PLLH         Missed Three Pointer (0/2 -  0 pt)     3FGA      68.0
# 467  P004888                                     Out      OUT      68.0
# 468  PJLX                                         In       IN      68.0
# 470  PCVM                            Def Rebound (3)        D      68.0
# 471  P006450                          Foul Drawn (8)       RV      68.0
# 473  P005160       Missed Two Pointer (6/9 -  16 pt)     2FGA      68.0
# 474  P005160                       Shot Rejected (2)       AG      68.0
# 479  P006450                               Block (2)       FV      68.0
# 481  PLLH                                        Out      OUT      68.0
# 482  P004888                                      In       IN      68.0
# 485                                     Time Out (3)     TOUT      71.0
# 486  P005160      Missed Two Pointer (6/10 -  16 pt)     2FGA      71.0
# 490  PCVM                 Two Pointer (2/4 -  10 pt)     2FGM      74.0
# 492  PJLX                                  Steal (2)       ST      74.0
# 493  PCVM                             Foul Drawn (4)       RV      74.0
# 495  PCVM               Free Throw In (1/1 -  11 pt)      FTM      74.0
# 496  PCVM               Free Throw In (2/2 -  12 pt)      FTM      74.0
# 498  P006450                         Def Rebound (5)        D      74.0
# 499  P004888                          Foul Drawn (4)       RV      74.0
# 501  P004888         Missed Free Throw (0/4 -  6 pt)      FTA      74.0
# 502  P004888             Free Throw In (1/5 -  7 pt)      FTM      74.0
# 503  P006450                              Assist (2)       AS      74.0
# 507  P004888                         Def Rebound (8)        D      74.0
# 508  P004888        Missed Two Pointer (3/8 -  7 pt)     2FGA      74.0
# 511  PJLX                                   Foul (4)       CM      74.0
# 513  PJLX                            Def Rebound (4)        D      74.0
# 514  PJLX         Missed Three Pointer (0/2 -  7 pt)     3FGA      74.0
# 517  PCVM                                   Foul (3)       CM      74.0
# 519  PCVM                             Foul Drawn (5)       RV      76.0
# 521  PCVM               Free Throw In (3/3 -  13 pt)      FTM      76.0
# 522  PCVM               Free Throw In (4/4 -  14 pt)      FTM      76.0
# 523  PCVM               Free Throw In (5/5 -  15 pt)      FTM      76.0
# 525  PCVM                                   Foul (4)       CM      76.0
# 528  PCVM        Missed Three Pointer (2/8 -  15 pt)     3FGA      77.0
# 534  P006450                                Foul (2)       CM      77.0
# 537  PCVM                               Turnover (4)       TO      79.0
#
#      POINTS_B         TEAM             home_team home_team_code    away_team  \
# 2         0.0  CSKA Moscow  Khimki Moscow Region            KHI  CSKA Moscow
#