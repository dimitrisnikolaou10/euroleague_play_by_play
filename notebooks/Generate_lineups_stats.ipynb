# %%
import os
import pandas as pd
import numpy as np
import re
import sys

# %%
# initialise empty dictionary
lineup_info = {}

# playtypes that will not be recorded
# acion types info in the list order
# begin period, end period, sub in, sub out, time out, end game, start_game, tv time out, tip off
# coaches fould, technical foul, bench foul, disqualifying foul
no_action_types = ["BP","EP","IN","OUT","TOUT","EG","SG","TOUT_TV","TPOFF","C","CMT","B","CMD"]


# helper function that returns the lineups as sorted lists
def return_sorted_lineups(row):
    home, away = [], []
    home.append(row["home_team_player_1"])
    home.append(row["home_team_player_2"])
    home.append(row["home_team_player_3"])
    home.append(row["home_team_player_4"])
    home.append(row["home_team_player_5"])
    away.append(row["away_team_player_1"])
    away.append(row["away_team_player_2"])
    away.append(row["away_team_player_3"])
    away.append(row["away_team_player_4"])
    away.append(row["away_team_player_5"])
    home, away = tuple(sorted(home)), tuple(sorted(away))
    return home, away

# go through all the data and create a dictionary that contains info on the lineups
data_path = "../data/adjusted_with_lineups/"
slash = "/"
season_parts = os.listdir(data_path) # generate the three distinct parts of the season (reg,pf,f4)
for part in season_parts:
    if part[0]==".":
        continue # if any hidden folders/files continue
    elif part[0]=="f": # meaning final4
        final_four = os.listdir(data_path + part + slash)
        for game in final_four:
            if '.csv' not in game: # again, avoid hidden files
                continue
            df = pd.read_csv(data_path + part + slash + game) # read, adjust, generate lineups, save with same name

            # add the home and away teams as keys (if they are not already added)
            home_team_code = df.loc[0,"home_team_code"]
            away_team_code = df.loc[0,"away_team_code"]
            if home_team_code not in lineup_info:
                lineup_info[home_team_code] = {}
            if away_team_code not in lineup_info:
                lineup_info[away_team_code] = {}
                
            # add the lineups as keys of the team dictionaries (if not already added)
            for i, row in df.iterrows():
                h, a = return_sorted_lineups(row)
                if h not in lineup_info[home_team_code]:
                    lineup_info[home_team_code][h] = {}
                    lineup_info[home_team_code][h]["seconds"] = 0
                if a not in lineup_info[away_team_code]:
                    lineup_info[away_team_code][a] = {}
                    lineup_info[away_team_code][a]["seconds"] = 0
                    
            # add the playtypes as keys of the lineups dictionaries (if not already added)
            for i, row in df.iterrows():
                play_type = row["PLAYTYPE"]
                for lineup in lineup_info[home_team_code].keys():
                    if play_type not in lineup_info[home_team_code][lineup]:
                        if play_type not in no_action_types:
                            lineup_info[home_team_code][lineup][play_type] = 0
                for lineup in lineup_info[away_team_code].keys():
                    if play_type not in lineup_info[away_team_code][lineup]:
                        if play_type not in no_action_types:
                            lineup_info[away_team_code][lineup][play_type] = 0     
                
    else:
        not_final_four = os.listdir(data_path + part + slash) # one layer more here as there are rounds
        for season_round in not_final_four:
            games_of_round = os.listdir(data_path + part + slash + season_round + slash)
            for game in games_of_round:
                if '.csv' not in game:
                    continue
                df = pd.read_csv(data_path + part + slash + season_round + slash + game)
                
                
                # add the home and away teams as keys (if they are not already added)
                home_team_code = df.loc[0,"home_team_code"]
                away_team_code = df.loc[0,"away_team_code"]
                if home_team_code not in lineup_info:
                    lineup_info[home_team_code] = {}
                if away_team_code not in lineup_info:
                    lineup_info[away_team_code] = {}

                # add the lineups as keys of the team dictionaries (if not already added)
                for i, row in df.iterrows():
                    h, a = return_sorted_lineups(row)
                    if h not in lineup_info[home_team_code]:
                        lineup_info[home_team_code][h] = {}
                        lineup_info[home_team_code][h]["seconds"] = 0
                    if a not in lineup_info[away_team_code]:
                        lineup_info[away_team_code][a] = {}
                        lineup_info[away_team_code][a]["seconds"] = 0

                # add the playtypes as keys of the lineups dictionaries (if not already added)
                for i, row in df.iterrows():
                    play_type = row["PLAYTYPE"].replace(" ", "")
                    for lineup in lineup_info[home_team_code].keys():
                        if play_type not in lineup_info[home_team_code][lineup]:
                            if play_type not in no_action_types:
                                lineup_info[home_team_code][lineup][play_type] = 0
                    for lineup in lineup_info[away_team_code].keys():
                        if play_type not in lineup_info[away_team_code][lineup]:
                            if play_type not in no_action_types:
                                lineup_info[away_team_code][lineup][play_type] = 0

# %%
# go through all the dictionaries and add the stats to the respective lineups
data_path = "../data/adjusted_with_lineups/"
slash = "/"
season_parts = os.listdir(data_path) # generate the three distinct parts of the season (reg,pf,f4)
for part in season_parts:
    if part[0]==".":
        continue # if any hidden folders/files continue
    elif part[0]=="f": # meaning final4
        final_four = os.listdir(data_path + part + slash)
        for game in final_four:
            if '.csv' not in game: # again, avoid hidden files
                continue
            df = pd.read_csv(data_path + part + slash + game) # read, adjust, generate lineups, save with same name
            

            # set the home and away team code
            home_team_code = df.loc[0,"home_team_code"]
            away_team_code = df.loc[0,"away_team_code"]            

            # add +1 & + minutes to the right lineup
            for i, row in df.iterrows():
                home_lineup, away_lineup = return_sorted_lineups(row)
                play_type = row["PLAYTYPE"].replace(" ", "")
                if play_type not in no_action_types:
                    if row["CODETEAM"] == home_team_code:
                        lineup_info[home_team_code][home_lineup][play_type] += 1
                        lineup_info[home_team_code][home_lineup]["seconds"] += row["SECONDS_TO_NEXT_PLAY"]
                    elif row["CODETEAM"] == away_team_code:
                        lineup_info[away_team_code][away_lineup][play_type] += 1
                        lineup_info[away_team_code][away_lineup]["seconds"] += row["SECONDS_TO_NEXT_PLAY"]

    else:
        not_final_four = os.listdir(data_path + part + slash) # one layer more here as there are rounds
        for season_round in not_final_four:
            games_of_round = os.listdir(data_path + part + slash + season_round + slash)
            for game in games_of_round:
                if '.csv' not in game:
                    continue
                df = pd.read_csv(data_path + part + slash + season_round + slash + game)
                
                # add the home and away teams as keys (if they are not already added)
                home_team_code = df.loc[0,"home_team_code"]
                away_team_code = df.loc[0,"away_team_code"]
                # add the playtypes as keys of the lineups dictionaries (if not already added)
                for i, row in df.iterrows():
                    home_lineup, away_lineup = return_sorted_lineups(row)
                    play_type = row["PLAYTYPE"].replace(" ", "")
                    if play_type not in no_action_types:
                        if row["CODETEAM"] == home_team_code:
                            lineup_info[home_team_code][home_lineup][play_type] += 1
                            lineup_info[home_team_code][home_lineup]["seconds"] += row["SECONDS_TO_NEXT_PLAY"]
                        elif row["CODETEAM"] == away_team_code:
                            lineup_info[away_team_code][away_lineup][play_type] += 1
                            lineup_info[away_team_code][away_lineup]["seconds"] += row["SECONDS_TO_NEXT_PLAY"]

# %%
# find the total number of lineups                                 
total_lineups = {}
for key, value in lineup_info.items():
    d = lineup_info[key]
    l = len(d)
    total_lineups[key] = l

# %%
# create a dictionary that contains lineup info only for lineups that played for 5 minutes or more together
adjusted_lineup_info = {}
min_sec = 300
for k,v in lineup_info.items():
        adjusted_lineup_info[k] = {key: value for key, value in lineup_info[k].items() if value["seconds"] >= min_sec}

# %%
# find the total number of adjusted lineups                                 
total_adjusted_lineups = {}
for key, value in adjusted_lineup_info.items():
    d = adjusted_lineup_info[key]
    l = len(d)
    total_adjusted_lineups[key] = l

# %%
# place the keys of the dictionary (teams) as a value of the lineups
for k,v in adjusted_lineup_info.items():
    for ke,va in v.items():
        va["TEAM"] = k

# %%
# unpack the first layer of the dictionary (as the team is now stored as a value)
all_lineups = {}
for k, v in adjusted_lineup_info.items():
    for ke,va in v.items():
        all_lineups[ke]=va

# %%
# create a dataframe out of this dictionary
df = pd.DataFrame(all_lineups).T
df.reset_index(inplace=True, drop=False)
df.rename(columns = {"level_0":"player1", "level_1":"player2", "level_2":"player3", "level_3":"player4", "level_4":"player5"}, inplace = True)

# %%
# store this dataframe as this is the data that will be used for clustering
df.to_csv("../data/lineup_stats.csv", index = False)

# %%
df
# Out:
#                        player1                player2               player3  \
# 0              ABALDE, ALBERTO      DOORNEKAMP, AARON          GREEN, ERICK
# 1              ABALDE, ALBERTO       DUBLJEVIC, BOJAN        MARTINEZ, RAFA
# 2              ABALDE, ALBERTO       DUBLJEVIC, BOJAN        MARTINEZ, RAFA
# 3              ABALDE, ALBERTO           GREEN, ERICK         PLEISS, TIBOR
# 4              ABALDE, ALBERTO           GREEN, ERICK         PLEISS, TIBOR
# 5              ABALDE, ALBERTO           GREEN, ERICK         PLEISS, TIBOR
# 6              ABALDE, ALBERTO         MARTINEZ, RAFA         PLEISS, TIBOR
# 7              ABALDE, ALBERTO         MARTINEZ, RAFA         PLEISS, TIBOR
# 8                 ABASS, AWUDU        BERTANS, DAIRIS     GUDAITIS, ARTURAS
# 9                  ADAMS, JOSH          BALBAY, DOGUS       DUNSTON, BRYANT
# 10                 ADAMS, JOSH         BROWN, DERRICK         DRAGIC, ZORAN
# 11                 ADAMS, JOSH          DRAGIC, ZORAN       DUNSTON, BRYANT
# 12                 ADAMS, JOSH        DUNSTON, BRYANT           LEDO, RICKY
# 13                 ADAMS, JOSH        DUNSTON, BRYANT          MOTUM, BROCK
# 14        AGRAVANIS, DIMITRIOS    MANTZARIS, VANGELIS         MCLEAN, JAMEL
# 15        AGRAVANIS, DIMITRIOS    MANTZARIS, VANGELIS         MCLEAN, JAMEL
# 16        AGRAVANIS, DIMITRIOS    MANTZARIS, VANGELIS         MCLEAN, JAMEL
# 17             ANDERSON, JAMES        ANDERSON, JAMES      JENKINS, CHARLES
# 18             ANDERSON, JAMES          GILL, ANTHONY      HONEYCUTT, TYLER
# 19             ANDERSON, JAMES          GILL, ANTHONY      JENKINS, CHARLES
# 20             ANDERSON, JAMES          GILL, ANTHONY      JENKINS, CHARLES
# 21             ANDERSON, JAMES          GILL, ANTHONY      JENKINS, CHARLES
# 22             ANDERSON, JAMES          GILL, ANTHONY      MARKOVIC, STEFAN
# 23             ANDERSON, JAMES          GILL, ANTHONY      MARKOVIC, STEFAN
# 24             ANDERSON, JAMES          GILL, ANTHONY      MARKOVIC, STEFAN
# 25             ANDERSON, JAMES       JENKINS, CHARLES      MARKOVIC, STEFAN
# 26             ANDERSON, JAMES       JENKINS, CHARLES         MONIA, SERGEY
# 27             ANDERSON, JAMES       JENKINS, CHARLES         MONIA, SERGEY
# 28             ANDERSON, JAMES       MARKOVIC, STEFAN         MONIA, SERGEY
# 29   ANTETOKOUNMPO, ATHANASIOS         CALATHES, NICK           GIST, JAMES
# ..                         ...                    ...                   ...
# 417        MANTZARIS, VANGELIS          MCLEAN, JAMEL   PAPAPETROU, IOANNIS
# 418        MANTZARIS, VANGELIS          MCLEAN, JAMEL     STRELNIEKS, JANIS
# 419        MANTZARIS, VANGELIS      MILUTINOV, NIKOLA  PAPANIKOLAOU, KOSTAS
# 420        MANTZARIS, VANGELIS      MILUTINOV, NIKOLA  PAPANIKOLAOU, KOSTAS
# 421        MANTZARIS, VANGELIS      MILUTINOV, NIKOLA   PAPAPETROU, IOANNIS
# 422        MANTZARIS, VANGELIS      MILUTINOV, NIKOLA   PAPAPETROU, IOANNIS
# 423        MANTZARIS, VANGELIS      MILUTINOV, NIKOLA   PAPAPETROU, IOANNIS
# 424        MANTZARIS, VANGELIS   PAPANIKOLAOU, KOSTAS   PAPAPETROU, IOANNIS
# 425        MANTZARIS, VANGELIS   PAPANIKOLAOU, KOSTAS   PAPAPETROU, IOANNIS
# 426           MARKOVIC, STEFAN          SHVED, ALEXEY       THOMAS, MALCOLM
# 427              MCCALLUM, RAY  MILOSAVLJEVIC, DRAGAN      NEDOVIC, NEMANJA
# 428              MCCALLUM, RAY       NEDOVIC, NEMANJA    SHERMADINI, GIORGI
# 429              MCCALLUM, RAY            SALIN, SASU    SHERMADINI, GIORGI
# 430              MCLEAN, JAMEL   PAPANIKOLAOU, KOSTAS   PAPAPETROU, IOANNIS
# 431              MCLEAN, JAMEL   PAPANIKOLAOU, KOSTAS   PRINTEZIS, GEORGIOS
# 432              MCLEAN, JAMEL    PAPAPETROU, IOANNIS   PRINTEZIS, GEORGIOS
# 433              MCLEAN, JAMEL    PAPAPETROU, IOANNIS        ROBERTS, BRIAN
# 434              MCLEAN, JAMEL         ROBERTS, BRIAN     STRELNIEKS, JANIS
# 435              MELLI, NICOLO        NUNNALLY, JAMES       SLOUKAS, KOSTAS
# 436              MELLI, NICOLO        NUNNALLY, JAMES       SLOUKAS, KOSTAS
# 437          MILUTINOV, NIKOLA   PAPANIKOLAOU, KOSTAS   PAPAPETROU, IOANNIS
# 438          MILUTINOV, NIKOLA   PAPANIKOLAOU, KOSTAS   PRINTEZIS, GEORGIOS
# 439          MILUTINOV, NIKOLA   PAPANIKOLAOU, KOSTAS   PRINTEZIS, GEORGIOS
# 440          MILUTINOV, NIKOLA   PAPANIKOLAOU, KOSTAS   PRINTEZIS, GEORGIOS
# 441          MILUTINOV, NIKOLA    PAPAPETROU, IOANNIS   PRINTEZIS, GEORGIOS
# 442          MILUTINOV, NIKOLA    PAPAPETROU, IOANNIS   PRINTEZIS, GEORGIOS
# 443          MILUTINOV, NIKOLA    PAPAPETROU, IOANNIS        ROBERTS, BRIAN
# 444          MILUTINOV, NIKOLA    PAPAPETROU, IOANNIS        ROBERTS, BRIAN
# 445          MILUTINOV, NIKOLA    PAPAPETROU, IOANNIS        ROBERTS, BRIAN
# 446          MILUTINOV, NIKOLA    PRINTEZIS, GEORGIOS        ROBERTS, BRIAN
#
#                     player4              player5 2FGA 2FGM 3FGA 3FGM  AG  \
# 0             PLEISS, TIBOR         THOMAS, WILL    9    6    2    3   1
# 1    SAN EMETERIO, FERNANDO         THOMAS, WILL    8    6    4   10   3
# 2              SASTRE, JOAN         THOMAS, WILL    7    8    8    5   2
# 3    SAN EMETERIO, FERNANDO         THOMAS, WILL    6    5    3    3   0
# 4              THOMAS, WILL      VAN ROSSOM, SAM    4    5    5    3   1
# 5              THOMAS, WILL       VIVES, GUILLEM    3    2    6    4   0
# 6              SASTRE, JOAN         THOMAS, WILL    5    6    4   10   1
# 7              THOMAS, WILL      VAN ROSSOM, SAM    4    7    4    7   0
# 8          JERRELLS, CURTIS        M'BAYE, AMATH    5    4    3    2   1
# 9          SIMON, KRUNOSLAV     STIMAC, VLADIMIR    5    4    1    4   0
# 10          DUNSTON, BRYANT     SIMON, KRUNOSLAV    7    4    2    1   0
# 11         SIMON, KRUNOSLAV     STIMAC, VLADIMIR   10    8    5    4   4
# 12         SIMON, KRUNOSLAV     STIMAC, VLADIMIR   23   25   19    8   5
# 13               MURIC, EDO     SIMON, KRUNOSLAV    2    5    7    4   0
# 14     PAPANIKOLAOU, KOSTAS     THOMPSON, HOLLIS    2    5    4    2   0
# 15      PAPAPETROU, IOANNIS    STRELNIEKS, JANIS    8    2    4    3   1
# 16        STRELNIEKS, JANIS     THOMPSON, HOLLIS    5    6    5    3   0
# 17            SHVED, ALEXEY     TODOROVIC, MARKO    7   10   13    3   1
# 18            SHVED, ALEXEY      THOMAS, MALCOLM    4    9    4    3   0
# 19         MARKOVIC, STEFAN     ROBINSON, THOMAS    6    8    4    2   2
# 20         ROBINSON, THOMAS        SHVED, ALEXEY   12    6    7    4   4
# 21            SHVED, ALEXEY      THOMAS, MALCOLM   59   73   95   47  13
# 22         ROBINSON, THOMAS        SHVED, ALEXEY   27   14   15   13   5
# 23            SHVED, ALEXEY      THOMAS, MALCOLM   38   48   38   19   4
# 24            SHVED, ALEXEY     TODOROVIC, MARKO    3   13    8    6   1
# 25         ROBINSON, THOMAS       ZUBKOV, ANDREY   10    8    4    0   1
# 26            SHVED, ALEXEY      THOMAS, MALCOLM   15    9   13    6   3
# 27            SHVED, ALEXEY     TODOROVIC, MARKO    4    9    3    5   0
# 28            SHVED, ALEXEY      THOMAS, MALCOLM    4    9   12    5   0
# 29            PAPPAS, NIKOS     SINGLETON, CHRIS    6   11    5    3   0
# ..                      ...                  ...  ...  ...  ...  ...  ..
# 417     PRINTEZIS, GEORGIOS    STRELNIEKS, JANIS    9    4    6    1   2
# 418        THOMPSON, HOLLIS        WILTJER, KYLE    4    7    8    3   0
# 419     PRINTEZIS, GEORGIOS  SPANOULIS, VASSILIS   33   48   24   13   9
# 420     PRINTEZIS, GEORGIOS    STRELNIEKS, JANIS   10   12   10    8   2
# 421     PRINTEZIS, GEORGIOS  SPANOULIS, VASSILIS   10   18   16    2   3
# 422     PRINTEZIS, GEORGIOS    STRELNIEKS, JANIS    7   18    6    1   0
# 423     SPANOULIS, VASSILIS          TILLIE, KIM    9   11   10    7   2
# 424     PRINTEZIS, GEORGIOS  SPANOULIS, VASSILIS    7    9    2    3   1
# 425     PRINTEZIS, GEORGIOS    STRELNIEKS, JANIS    3    7    4    2   0
# 426          VIALTSEV, EGOR       ZUBKOV, ANDREY    6    4    6    3   1
# 427      SHERMADINI, GIORGI       SUAREZ, CARLOS   11    9    6    1   2
# 428          SUAREZ, CARLOS      WACZYNSKI, ADAM    8    7    7    4   2
# 429          SUAREZ, CARLOS      WACZYNSKI, ADAM   11   11    7    2   2
# 430     SPANOULIS, VASSILIS    STRELNIEKS, JANIS    0    9    8    1   0
# 431          ROBERTS, BRIAN    STRELNIEKS, JANIS    8    7    4    2   1
# 432          ROBERTS, BRIAN  SPANOULIS, VASSILIS   11    9    9    1   1
# 433       STRELNIEKS, JANIS     THOMPSON, HOLLIS    4    5    6    3   2
# 434        THOMPSON, HOLLIS        WILTJER, KYLE    4    4    3    6   2
# 435         THOMPSON, JASON      WANAMAKER, BRAD   13   12    4    4   2
# 436             VESELY, JAN      WANAMAKER, BRAD   12   14    8    4   2
# 437     PRINTEZIS, GEORGIOS       ROBERTS, BRIAN   11   14    3    1   1
# 438          ROBERTS, BRIAN  SPANOULIS, VASSILIS   15   14   16    8   4
# 439          ROBERTS, BRIAN    STRELNIEKS, JANIS   12   16    6    3   2
# 440          ROBERTS, BRIAN     THOMPSON, HOLLIS   23   25   14    4   3
# 441          ROBERTS, BRIAN  SPANOULIS, VASSILIS   18   19    5    2   0
# 442          ROBERTS, BRIAN     THOMPSON, HOLLIS    7    9    3    3   0
# 443     SPANOULIS, VASSILIS     THOMPSON, HOLLIS    3    8    3    4   1
# 444     SPANOULIS, VASSILIS          TILLIE, KIM    2   13    4    2   0
# 445       STRELNIEKS, JANIS     THOMPSON, HOLLIS    5    5    3    3   0
# 446       STRELNIEKS, JANIS     THOMPSON, HOLLIS    5    3    3    2   1
#
#       ...   FTA FTM  FV   O OF  RV  ST TEAM  TO seconds
# 0     ...     3   6   2   3  0   6   3  PAM   3     448
# 1     ...     1   3   0   2  1   7   3  PAM   4     516
# 2     ...     0   6   1   5  0  11   2  PAM   1     530
# 3     ...     0   2   0   3  0   6   1  PAM   4     343
# 4     ...     1   4   2   3  0   5   1  PAM   2     330
# 5     ...     2   3   0   3  1   4   3  PAM   6     341
# 6     ...     0   5   2   2  1  11   1  PAM   7     485
# 7     ...     0   5   1   5  0   3   2  PAM   4     454
# 8     ...     3   3   1   4  0   5   1  MIL   3     307
# 9     ...     1   1   2   1  0   6   0  IST   2     377
# 10    ...     0   4   3   2  0   3   0  IST   5     328
# 11    ...     4   6   0   6  1  11   1  IST   3     412
# 12    ...     5   9   3  15  0  18   5  IST  12    1276
# 13    ...     0   2   1   1  0   3   3  IST   4     371
# 14    ...     2   6   1   1  1   8   2  OLY   4     331
# 15    ...     2   3   0   2  1   9   1  OLY   5     394
# 16    ...     2   4   0   6  2   6   0  OLY   3     360
# 17    ...     0   1   3   6  0   4   6  KHI   9     582
# 18    ...     4   1   1   0  0   8   1  KHI   6     359
# 19    ...     2   4   1   2  0   4   3  KHI   3     359
# 20    ...     2   8   1   9  1   5   3  KHI   3     397
# 21    ...    11  38  10  44  3  63  32  KHI  49    4947
# 22    ...     4  21   5  11  3  25   6  KHI  12    1446
# 23    ...     4  18   2  29  4  39  14  KHI  24    2569
# 24    ...     1   8   1   4  0  12   3  KHI   3     644
# 25    ...     3   2   1   8  0   5   2  KHI   3     391
# 26    ...     0   8   2   6  1  11   2  KHI   7     787
# 27    ...     1   2   1   1  0   9   1  KHI   2     387
# 28    ...     0  12   1   3  0  14   3  KHI   4     606
# 29    ...     2   5   1   3  2   9   5  PAN   4     467
# ..    ...    ..  ..  ..  .. ..  ..  ..  ...  ..     ...
# 417   ...     1   2   0   5  1   7   5  OLY   1     344
# 418   ...     2  14   1   8  1  14   1  OLY  10     498
# 419   ...     3  30   3  14  2  45  14  OLY  19    2203
# 420   ...     2  10   3   9  1  13   7  OLY  11     864
# 421   ...     4  11   2  10  1  10   3  OLY   5     738
# 422   ...     3   5   1   2  0  14   2  OLY   5     623
# 423   ...     1   4   1   9  1  10   1  OLY   3     559
# 424   ...     2   5   0   2  0  10   3  OLY   3     340
# 425   ...     3   5   1   3  0   5   0  OLY   2     316
# 426   ...     0   3   0   3  2   5   3  KHI   6     415
# 427   ...     3   5   0   5  0  15   2  MAL   6     484
# 428   ...     1   6   3   3  0   9   2  MAL   5     449
# 429   ...     1   2   1   7  1  10   3  MAL   7     530
# 430   ...     1   9   1   2  1   8   1  OLY   4     368
# 431   ...     6   9   0   3  1  11   5  OLY   6     467
# 432   ...     7  16   0   8  1  13   0  OLY   6     569
# 433   ...     0   4   1   4  0   8   0  OLY   5     403
# 434   ...     1   4   0   1  2   9   0  OLY   4     378
# 435   ...     2   8   0   6  1  11   9  ULK   4     678
# 436   ...     2   5   2   3  0   7   7  ULK  10     876
# 437   ...     0   4   2   1  3  12   2  OLY   7     542
# 438   ...     4  16   1  13  0  20   7  OLY   6    1061
# 439   ...     0   8   0   9  1  14   4  OLY  10     739
# 440   ...     1   5   1   9  1  18   8  OLY  14    1174
# 441   ...     2  13   2  10  0  12   4  OLY   7     864
# 442   ...     1   4   1   4  1   6   1  OLY   3     425
# 443   ...     2   5   1   1  0   9   2  OLY   5     390
# 444   ...     0   2   0   3  1   2   0  OLY   9     538
# 445   ...     1   6   2   1  2   6   0  OLY   5     390
# 446   ...     2   7   0   0  0   9   2  OLY   4     433
#
# [447 rows x 24 columns]
