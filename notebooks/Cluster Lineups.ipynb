# %%
import os
import pandas as pd
import numpy as np
import re
import sys

# %%
# initialise empty dictionary
lineup_info = {}

# playtypes that will not be recorded
# acion types info in the list order
# begin period, end period, sub in, sub out, time out, end game, start_game, tv time out, tip off
# coaches fould, technical foul, bench foul, disqualifying foul
no_action_types = ["BP","EP","IN","OUT","TOUT","EG","SG","TOUT_TV","TPOFF","C","CMT","B","CMD"]


# helper function that returns the lineups as sorted lists
def return_sorted_lineups(row):
    home, away = [], []
    home.append(row["home_team_player_1"])
    home.append(row["home_team_player_2"])
    home.append(row["home_team_player_3"])
    home.append(row["home_team_player_4"])
    home.append(row["home_team_player_5"])
    away.append(row["away_team_player_1"])
    away.append(row["away_team_player_2"])
    away.append(row["away_team_player_3"])
    away.append(row["away_team_player_4"])
    away.append(row["away_team_player_5"])
    home, away = tuple(sorted(home)), tuple(sorted(away))
    return home, away

# go through all the data and create a dictionary that contains info on the lineups
data_path = "../data/adjusted_with_lineups/"
slash = "/"
season_parts = os.listdir(data_path) # generate the three distinct parts of the season (reg,pf,f4)
for part in season_parts:
    if part[0]==".":
        continue # if any hidden folders/files continue
    elif part[0]=="f": # meaning final4
        final_four = os.listdir(data_path + part + slash)
        for game in final_four:
            if '.csv' not in game: # again, avoid hidden files
                continue
            df = pd.read_csv(data_path + part + slash + game) # read, adjust, generate lineups, save with same name

            # add the home and away teams as keys (if they are not already added)
            home_team_code = df.loc[0,"home_team_code"]
            away_team_code = df.loc[0,"away_team_code"]
            if home_team_code not in lineup_info:
                lineup_info[home_team_code] = {}
            if away_team_code not in lineup_info:
                lineup_info[away_team_code] = {}
                
            # add the lineups as keys of the team dictionaries (if not already added)
            for i, row in df.iterrows():
                h, a = return_sorted_lineups(row)
                if h not in lineup_info[home_team_code]:
                    lineup_info[home_team_code][h] = {}
                    lineup_info[home_team_code][h]["seconds"] = 0
                if a not in lineup_info[away_team_code]:
                    lineup_info[away_team_code][a] = {}
                    lineup_info[away_team_code][a]["seconds"] = 0
                    
            # add the playtypes as keys of the lineups dictionaries (if not already added)
            for i, row in df.iterrows():
                play_type = row["PLAYTYPE"]
                for lineup in lineup_info[home_team_code].keys():
                    if play_type not in lineup_info[home_team_code][lineup]:
                        if play_type not in no_action_types:
                            lineup_info[home_team_code][lineup][play_type] = 0
                for lineup in lineup_info[away_team_code].keys():
                    if play_type not in lineup_info[away_team_code][lineup]:
                        if play_type not in no_action_types:
                            lineup_info[away_team_code][lineup][play_type] = 0     
                
    else:
        not_final_four = os.listdir(data_path + part + slash) # one layer more here as there are rounds
        for season_round in not_final_four:
            games_of_round = os.listdir(data_path + part + slash + season_round + slash)
            for game in games_of_round:
                if '.csv' not in game:
                    continue
                df = pd.read_csv(data_path + part + slash + season_round + slash + game)
                
                
                # add the home and away teams as keys (if they are not already added)
                home_team_code = df.loc[0,"home_team_code"]
                away_team_code = df.loc[0,"away_team_code"]
                if home_team_code not in lineup_info:
                    lineup_info[home_team_code] = {}
                if away_team_code not in lineup_info:
                    lineup_info[away_team_code] = {}

                # add the lineups as keys of the team dictionaries (if not already added)
                for i, row in df.iterrows():
                    h, a = return_sorted_lineups(row)
                    if h not in lineup_info[home_team_code]:
                        lineup_info[home_team_code][h] = {}
                        lineup_info[home_team_code][h]["seconds"] = 0
                    if a not in lineup_info[away_team_code]:
                        lineup_info[away_team_code][a] = {}
                        lineup_info[away_team_code][a]["seconds"] = 0

                # add the playtypes as keys of the lineups dictionaries (if not already added)
                for i, row in df.iterrows():
                    play_type = row["PLAYTYPE"].replace(" ", "")
                    for lineup in lineup_info[home_team_code].keys():
                        if play_type not in lineup_info[home_team_code][lineup]:
                            if play_type not in no_action_types:
                                lineup_info[home_team_code][lineup][play_type] = 0
                    for lineup in lineup_info[away_team_code].keys():
                        if play_type not in lineup_info[away_team_code][lineup]:
                            if play_type not in no_action_types:
                                lineup_info[away_team_code][lineup][play_type] = 0

# %%
# go through all the dictionaries and add the stats to the respective lineups
data_path = "../data/adjusted_with_lineups/"
slash = "/"
season_parts = os.listdir(data_path) # generate the three distinct parts of the season (reg,pf,f4)
for part in season_parts:
    if part[0]==".":
        continue # if any hidden folders/files continue
    elif part[0]=="f": # meaning final4
        final_four = os.listdir(data_path + part + slash)
        for game in final_four:
            if '.csv' not in game: # again, avoid hidden files
                continue
            df = pd.read_csv(data_path + part + slash + game) # read, adjust, generate lineups, save with same name
            

            # set the home and away team code
            home_team_code = df.loc[0,"home_team_code"]
            away_team_code = df.loc[0,"away_team_code"]            

            # add +1 & + minutes to the right lineup
            for i, row in df.iterrows():
                home_lineup, away_lineup = return_sorted_lineups(row)
                play_type = row["PLAYTYPE"].replace(" ", "")
                if play_type not in no_action_types:
                    if row["CODETEAM"] == home_team_code:
                        lineup_info[home_team_code][home_lineup][play_type] += 1
                        lineup_info[home_team_code][home_lineup]["seconds"] += row["SECONDS_TO_NEXT_PLAY"]
                    elif row["CODETEAM"] == away_team_code:
                        lineup_info[away_team_code][away_lineup][play_type] += 1
                        lineup_info[away_team_code][away_lineup]["seconds"] += row["SECONDS_TO_NEXT_PLAY"]

    else:
        not_final_four = os.listdir(data_path + part + slash) # one layer more here as there are rounds
        for season_round in not_final_four:
            games_of_round = os.listdir(data_path + part + slash + season_round + slash)
            for game in games_of_round:
                if '.csv' not in game:
                    continue
                df = pd.read_csv(data_path + part + slash + season_round + slash + game)
                
                # add the home and away teams as keys (if they are not already added)
                home_team_code = df.loc[0,"home_team_code"]
                away_team_code = df.loc[0,"away_team_code"]
                # add the playtypes as keys of the lineups dictionaries (if not already added)
                for i, row in df.iterrows():
                    home_lineup, away_lineup = return_sorted_lineups(row)
                    play_type = row["PLAYTYPE"].replace(" ", "")
                    if play_type not in no_action_types:
                        if row["CODETEAM"] == home_team_code:
                            lineup_info[home_team_code][home_lineup][play_type] += 1
                            lineup_info[home_team_code][home_lineup]["seconds"] += row["SECONDS_TO_NEXT_PLAY"]
                        elif row["CODETEAM"] == away_team_code:
                            lineup_info[away_team_code][away_lineup][play_type] += 1
                            lineup_info[away_team_code][away_lineup]["seconds"] += row["SECONDS_TO_NEXT_PLAY"]

# %%
# find the total number of lineups                                 
total_lineups = {}
for key, value in lineup_info.items():
    d = lineup_info[key]
    l = len(d)
    total_lineups[key] = l

# %%
# create a dictionary that contains lineup info only for lineups that played for 5 minutes or more together
adjusted_lineup_info = {}
min_sec = 300
for k,v in lineup_info.items():
        adjusted_lineup_info[k] = {key: value for key, value in lineup_info[k].items() if value["seconds"] >= min_sec}

# %%
# find the total number of adjusted lineups                                 
total_adjusted_lineups = {}
for key, value in adjusted_lineup_info.items():
    d = adjusted_lineup_info[key]
    l = len(d)
    total_adjusted_lineups[key] = l

# %%
# place the keys of the dictionary (teams) as a value of the lineups
for k,v in adjusted_lineup_info.items():
    for ke,va in v.items():
        va["TEAM"] = k

# %%
# unpack the first layer of the dictionary (as the team is now stored as a value)
all_lineups = {}
for k, v in adjusted_lineup_info.items():
    for ke,va in v.items():
        all_lineups[ke]=va

# %%
# create a dataframe out of this dictionary
df = pd.DataFrame(all_lineups).T
df.reset_index(inplace=True, drop=False)
df.rename(columns = {"level_0":"player1", "level_1":"player2", "level_2":"player3", "level_3":"player4", "level_4":"player5"}, inplace = True)

# %%
# store this dataframe as this is the data that will be used for clustering
df.to_csv("../data/lineup_stats.csv", index = False)

# %%
df
# Out:
#                      player1                player2                player3  \
# 0              AYON, GUSTAVO      CAMPAZZO, FACUNDO        CAUSEUR, FABIEN
# 1            CARROLL, JAYCEE        CAUSEUR, FABIEN           DONCIC, LUKA
# 2              AYON, GUSTAVO        CAUSEUR, FABIEN           DONCIC, LUKA
# 3              AYON, GUSTAVO        CAUSEUR, FABIEN           DONCIC, LUKA
# 4          CAMPAZZO, FACUNDO        CAUSEUR, FABIEN        TAVARES, WALTER
# 5          CAMPAZZO, FACUNDO        CAUSEUR, FABIEN        TAVARES, WALTER
# 6            CARROLL, JAYCEE           DONCIC, LUKA        FERNANDEZ, RUDY
# 7            CARROLL, JAYCEE           DONCIC, LUKA        FERNANDEZ, RUDY
# 8          CAMPAZZO, FACUNDO        CAUSEUR, FABIEN           DONCIC, LUKA
# 9            CARROLL, JAYCEE        FERNANDEZ, RUDY        RANDLE, CHASSON
# 10           CAUSEUR, FABIEN           DONCIC, LUKA          REYES, FELIPE
# 11           CARROLL, JAYCEE           DONCIC, LUKA        MACIULIS, JONAS
# 12         CAMPAZZO, FACUNDO        FERNANDEZ, RUDY        TAVARES, WALTER
# 13         CAMPAZZO, FACUNDO        CAUSEUR, FABIEN      RANDOLPH, ANTHONY
# 14           CAUSEUR, FABIEN           DONCIC, LUKA      RANDOLPH, ANTHONY
# 15         CAMPAZZO, FACUNDO        CARROLL, JAYCEE        FERNANDEZ, RUDY
# 16         CAMPAZZO, FACUNDO        CARROLL, JAYCEE      RANDOLPH, ANTHONY
# 17             AYON, GUSTAVO      CAMPAZZO, FACUNDO        CAUSEUR, FABIEN
# 18             AYON, GUSTAVO      CAMPAZZO, FACUNDO        CAUSEUR, FABIEN
# 19             AYON, GUSTAVO      CAMPAZZO, FACUNDO        CAUSEUR, FABIEN
# 20              DONCIC, LUKA        FERNANDEZ, RUDY        MACIULIS, JONAS
# 21         CAMPAZZO, FACUNDO           DONCIC, LUKA        TAVARES, WALTER
# 22           CAUSEUR, FABIEN           DONCIC, LUKA      RANDOLPH, ANTHONY
# 23             AYON, GUSTAVO        CARROLL, JAYCEE           DONCIC, LUKA
# 24         CAMPAZZO, FACUNDO        FERNANDEZ, RUDY        RANDLE, CHASSON
# 25         CAMPAZZO, FACUNDO           DONCIC, LUKA      RANDOLPH, ANTHONY
# 26             AYON, GUSTAVO      CAMPAZZO, FACUNDO        CAUSEUR, FABIEN
# 27             AYON, GUSTAVO        CAUSEUR, FABIEN           DONCIC, LUKA
# 28             AYON, GUSTAVO        CARROLL, JAYCEE           DONCIC, LUKA
# 29             AYON, GUSTAVO      CAMPAZZO, FACUNDO        CAUSEUR, FABIEN
# ..                       ...                    ...                    ...
# 417           CALATHES, NICK          PAPPAS, NIKOS           RIVERS, K.C.
# 418           DENMON, MARCUS            JAMES, MIKE          LOJESKI, MATT
# 419  ANTETOKOUNMPO, THANASIS            GIST, JAMES      LEKAVICIUS, LUKAS
# 420  ANTETOKOUNMPO, THANASIS         CALATHES, NICK          PAPPAS, NIKOS
# 421         AUGUSTINE, JAMES           BROOKS, JEFF           DIEZ, DANIEL
# 422         AUGUSTINE, JAMES          DIAZ, ALBERTO  MILOSAVLJEVIC, DRAGAN
# 423         AUGUSTINE, JAMES           BROOKS, JEFF          DIAZ, ALBERTO
# 424         AUGUSTINE, JAMES           BROOKS, JEFF          DIAZ, ALBERTO
# 425         AUGUSTINE, JAMES           BROOKS, JEFF          MCCALLUM, RAY
# 426         AUGUSTINE, JAMES          MCCALLUM, RAY  MILOSAVLJEVIC, DRAGAN
# 427         AUGUSTINE, JAMES           DIEZ, DANIEL          MCCALLUM, RAY
# 428            MCCALLUM, RAY            SALIN, SASU     SHERMADINI, GIORGI
# 429            DIAZ, ALBERTO            SALIN, SASU     SHERMADINI, GIORGI
# 430         AUGUSTINE, JAMES          DIAZ, ALBERTO       NEDOVIC, NEMANJA
# 431         AUGUSTINE, JAMES          MCCALLUM, RAY       NEDOVIC, NEMANJA
# 432         AUGUSTINE, JAMES          MCCALLUM, RAY  MILOSAVLJEVIC, DRAGAN
# 433         AUGUSTINE, JAMES           DIEZ, DANIEL          MCCALLUM, RAY
# 434            MCCALLUM, RAY  MILOSAVLJEVIC, DRAGAN       NEDOVIC, NEMANJA
# 435         AUGUSTINE, JAMES           BROOKS, JEFF          MCCALLUM, RAY
# 436         AUGUSTINE, JAMES           BROOKS, JEFF          MCCALLUM, RAY
# 437             BROOKS, JEFF          DIAZ, ALBERTO       NEDOVIC, NEMANJA
# 438         AUGUSTINE, JAMES           BROOKS, JEFF          DIAZ, ALBERTO
# 439            MCCALLUM, RAY       NEDOVIC, NEMANJA     SHERMADINI, GIORGI
# 440             BROOKS, JEFF          DIAZ, ALBERTO            SALIN, SASU
# 441         AUGUSTINE, JAMES           BROOKS, JEFF          DIAZ, ALBERTO
# 442         AUGUSTINE, JAMES          MCCALLUM, RAY            SALIN, SASU
# 443         AUGUSTINE, JAMES           BROOKS, JEFF          DIAZ, ALBERTO
# 444             BROOKS, JEFF          MCCALLUM, RAY  MILOSAVLJEVIC, DRAGAN
# 445             BROOKS, JEFF          MCCALLUM, RAY            SALIN, SASU
# 446             BROOKS, JEFF          DIAZ, ALBERTO  MILOSAVLJEVIC, DRAGAN
#
#                    player4             player5 2FGA 2FGM 3FGA 3FGM AG   ...    \
# 0             DONCIC, LUKA       REYES, FELIPE   12   14    5    4  1   ...
# 1          TAVARES, WALTER     THOMPKINS, TREY    2    4    6    3  0   ...
# 2            REYES, FELIPE     TAYLOR, JEFFERY    9    8    4    4  3   ...
# 3          TAYLOR, JEFFERY     THOMPKINS, TREY   17   17    9    1  2   ...
# 4          TAYLOR, JEFFERY     THOMPKINS, TREY   13   18   16    8  1   ...
# 5          THOMPKINS, TREY        YUSTA, SANTI   21   34   24   15  4   ...
# 6            REYES, FELIPE     THOMPKINS, TREY   14   17   12    5  2   ...
# 7          MACIULIS, JONAS       REYES, FELIPE   10   12   10    7  1   ...
# 8          MACIULIS, JONAS     TAVARES, WALTER    5   11    6    2  0   ...
# 9            REYES, FELIPE     THOMPKINS, TREY    7    6    3    4  1   ...
# 10         TAYLOR, JEFFERY     THOMPKINS, TREY    6    4    6    1  0   ...
# 11           REYES, FELIPE     TAYLOR, JEFFERY    9   10   12    7  2   ...
# 12         TAYLOR, JEFFERY     THOMPKINS, TREY    7    4    8    7  0   ...
# 13         TAVARES, WALTER     TAYLOR, JEFFERY   10   12    4    5  2   ...
# 14         TAVARES, WALTER     TAYLOR, JEFFERY    7   13   11    1  1   ...
# 15           REYES, FELIPE     THOMPKINS, TREY    8   12   11    3  2   ...
# 16         TAVARES, WALTER     TAYLOR, JEFFERY   18   26   13   12  2   ...
# 17         FERNANDEZ, RUDY   RANDOLPH, ANTHONY    3    6    5    2  0   ...
# 18         FERNANDEZ, RUDY     THOMPKINS, TREY    9   10    5    4  1   ...
# 19       RANDOLPH, ANTHONY     TAYLOR, JEFFERY    3    4    2    6  0   ...
# 20           REYES, FELIPE     TAYLOR, JEFFERY    4    6   10    3  0   ...
# 21         TAYLOR, JEFFERY     THOMPKINS, TREY   11    9   12    5  1   ...
# 22           REYES, FELIPE     TAYLOR, JEFFERY    8    7    5    2  1   ...
# 23         FERNANDEZ, RUDY     THOMPKINS, TREY    4    5    5    4  1   ...
# 24         TAVARES, WALTER     THOMPKINS, TREY    4    6    6    0  1   ...
# 25           REYES, FELIPE     TAYLOR, JEFFERY    6    8    7    4  0   ...
# 26           REYES, FELIPE     TAYLOR, JEFFERY    4    9    7    1  0   ...
# 27       RANDOLPH, ANTHONY     TAYLOR, JEFFERY    4   14    6    6  0   ...
# 28           REYES, FELIPE     TAYLOR, JEFFERY    5    4    4    5  0   ...
# 29            DONCIC, LUKA     MACIULIS, JONAS    4    1    6    4  1   ...
# ..                     ...                 ...  ...  ...  ...  ... ..   ...
# 417       SINGLETON, CHRIS     VOUGIOUKAS, IAN    3    6    5    4  0   ...
# 418         PAYNE, ADREIAN    SINGLETON, CHRIS    3    7    5    3  0   ...
# 419          LOJESKI, MATT    SINGLETON, CHRIS   10   10    4    6  1   ...
# 420             RIVERS, KC    SINGLETON, CHRIS    5    6    4    4  2   ...
# 421          MCCALLUM, RAY    NEDOVIC, NEMANJA   31   26   14   14  4   ...
# 422       NEDOVIC, NEMANJA      SUAREZ, CARLOS   14   12    6    5  0   ...
# 423           DIEZ, DANIEL    NEDOVIC, NEMANJA   13    8   10    3  0   ...
# 424  MILOSAVLJEVIC, DRAGAN    NEDOVIC, NEMANJA   12   25   13   11  0   ...
# 425  MILOSAVLJEVIC, DRAGAN    NEDOVIC, NEMANJA   26   36   22    9  0   ...
# 426       NEDOVIC, NEMANJA      SUAREZ, CARLOS   12   11   10    5  3   ...
# 427       NEDOVIC, NEMANJA      SUAREZ, CARLOS    4   15    5    4  1   ...
# 428         SUAREZ, CARLOS     WACZYNSKI, ADAM   11   11    7    2  2   ...
# 429         SUAREZ, CARLOS     WACZYNSKI, ADAM    7    9   14    3  0   ...
# 430         SUAREZ, CARLOS     WACZYNSKI, ADAM   13   14   19    9  0   ...
# 431         SUAREZ, CARLOS     WACZYNSKI, ADAM   15   18    9   11  2   ...
# 432            SALIN, SASU      SUAREZ, CARLOS   23   28   16   17  5   ...
# 433            SALIN, SASU      SUAREZ, CARLOS    6   11    1    0  1   ...
# 434     SHERMADINI, GIORGI      SUAREZ, CARLOS   11    9    6    1  2   ...
# 435  MILOSAVLJEVIC, DRAGAN     WACZYNSKI, ADAM   12    5    3    1  1   ...
# 436       NEDOVIC, NEMANJA     WACZYNSKI, ADAM   21   25   14   12  7   ...
# 437            OKOUO, VINY     WACZYNSKI, ADAM    7    5    7    3  0   ...
# 438       NEDOVIC, NEMANJA     WACZYNSKI, ADAM   11   17   10   10  2   ...
# 439         SUAREZ, CARLOS     WACZYNSKI, ADAM    8    7    7    4  2   ...
# 440     SHERMADINI, GIORGI     WACZYNSKI, ADAM    9    7    6    2  1   ...
# 441            SALIN, SASU     WACZYNSKI, ADAM    5    8    6    4  1   ...
# 442         SUAREZ, CARLOS     WACZYNSKI, ADAM    6    9    6    2  1   ...
# 443  MILOSAVLJEVIC, DRAGAN         SALIN, SASU   11   11   10    3  1   ...
# 444            SALIN, SASU  SHERMADINI, GIORGI   16   13   12    6  1   ...
# 445     SHERMADINI, GIORGI     WACZYNSKI, ADAM   10   11    7    8  1   ...
# 446       NEDOVIC, NEMANJA  SHERMADINI, GIORGI    3    4    6    1  1   ...
#
#     FTA FTM  FV   O OF  RV  ST TEAM  TO seconds
# 0     1   7   1   4  3   9   5  MAD   8     678
# 1     2  10   0   4  0  11   1  MAD   2     348
# 2     1   5   0   5  1  11   1  MAD   8     426
# 3     7   5   3   7  0  20   8  MAD   7     790
# 4     5  11   2   8  3  16   8  MAD  11     941
# 5     0   8   6  13  1  29   8  MAD  25    1826
# 6     3   9   2  12  3  19   3  MAD   8     779
# 7     1  10   2   4  1  12   5  MAD   6     691
# 8     0   1   1   1  0   5   1  MAD   6     404
# 9     1   7   1   2  0   7   0  MAD   2     383
# 10    2   6   0   3  0   3   2  MAD   1     322
# 11    4  18   3   6  2  21   6  MAD   4     597
# 12    5   7   2   8  0   9   5  MAD   7     460
# 13    6  12   1   8  2  19   5  MAD   8     481
# 14    3   7   1   6  3  15   3  MAD   9     487
# 15    4  12   3   5  1  15   8  MAD   6     702
# 16    4   3  10  11  3  14   6  MAD   8     929
# 17    1   1   0   2  0   5   1  MAD   1     305
# 18    1   3   2   4  0   5   2  MAD   2     477
# 19    0   1   1   3  0   6   1  MAD   3     305
# 20    3   7   1   7  1   9   2  MAD   6     347
# 21    1   0   3  11  0  10   2  MAD   6     597
# 22    2   3   0   5  0   8   2  MAD   2     314
# 23    1  16   0   2  0  10   2  MAD   7     436
# 24    0   3   0   2  0   6   0  MAD   2     304
# 25    1  10   0   5  0  10   2  MAD   1     338
# 26    1   2   1   4  0   7   1  MAD   2     397
# 27    4  11   3   2  0  12   8  MAD   5     527
# 28    4  10   1   5  0  11   2  MAD   3     316
# 29    1   9   0   1  0   6   2  MAD   0     317
# ..   ..  ..  ..  .. ..  ..  ..  ...  ..     ...
# 417   2   4   1   3  1   7   2  PAN   1     350
# 418   0   4   1   3  0   4   1  PAN   1     307
# 419   2   5   5   6  0  14   2  PAN  10     715
# 420   2  10   2   3  1  10   1  PAN   3     409
# 421   2   2   1  22  0  11   4  MAL   6    1221
# 422   4   8   1   3  0  12   4  MAL   6     797
# 423   0   4   0   7  2   6   2  MAL   2     593
# 424   4   9   3   8  0  21   5  MAL  10    1033
# 425   5  10   6  20  3  25   7  MAL  17    1551
# 426   2   8   1   8  2   8   5  MAL   9     618
# 427   2  11   0   6  1  13   1  MAL   3     441
# 428   1   2   1   7  1  10   3  MAL   7     530
# 429   0   7   1   7  0  12   2  MAL   5     602
# 430   5  19   0  13  0  20   4  MAL   8    1072
# 431   5  13   2   7  0  14   1  MAL   4     871
# 432   3  16   4  18  1  20  11  MAL  10    1422
# 433   1   0   0   4  0   7   2  MAL   2     320
# 434   3   5   0   5  0  15   2  MAL   6     484
# 435   3   2   0   8  0   3   3  MAL   4     455
# 436   5  10   1  16  0  17  10  MAL  14    1306
# 437   0   0   2   5  1   4   3  MAL   2     341
# 438   1  13   2  10  0   8   7  MAL   5     628
# 439   1   6   3   3  0   9   2  MAL   5     449
# 440   0   3   0   6  1   6   0  MAL   7     432
# 441   0   4   0   3  3   8   8  MAL   7     502
# 442   1   5   0   5  0  10   4  MAL   2     365
# 443   1   6   2   9  1  17   3  MAL   6     608
# 444   1   3   1   7  2  14   3  MAL   8     892
# 445   0   5   1   6  0  10   4  MAL   5     689
# 446   1   1   1   3  1   5   2  MAL   5     301
#
# [447 rows x 24 columns]
